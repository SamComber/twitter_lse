# %%
# load dependencies
import tweepy
import dataset
import json
from sqlalchemy.exc import ProgrammingError
import textblob
import time
import numpy as np
import pandas as pd
import sqlite3
import os

# create sqlite db if none exists, else append
db = dataset.connect("sqlite:///tweets_lse.db")

# set api constants
TWITTER_APP_KEY = 'pfekrUmzHx0WY4gNjQaIsjmjH'
TWITTER_APP_SECRET = 'OkZxpDJIMEtttGnUWigqhGvK4WqNnZLDLg79codmz56JZBhO9Q'
TWITTER_KEY = '1439343834-7xzhsIyOJYETIwiMaaZXj3qm1gQq0bge1QwgwRy'
TWITTER_SECRET = 'wjyIx0p1l7P2OB9jarfmRR500yzn7MOogJiSA9HEAh4qz'

# set OAuth authentication
auth = tweepy.OAuthHandler(TWITTER_APP_KEY, TWITTER_APP_SECRET)
auth.set_access_token(TWITTER_KEY, TWITTER_SECRET)

# create API object to pull twitter data, passing in authentication
api = tweepy.API(auth, 
                 retry_count = 5, # default number of retries to attempt when error occurs
                 retry_delay = 5, # number of seconds to wait between retries
                 wait_on_rate_limit = True, # Whether or not to automatically wait for rate limits to replenish
                 wait_on_rate_limit_notify = True) # Whether or not to print a notification when Tweepy is waiting for rate limits to replenish

# create class that inherits from streamlistener object
class StreamListener(tweepy.StreamListener):
    
    # override on_status method to define our own functionality     
    def on_status(self, status):
        
        # print all tweets that are not retweets         
        if hasattr(status, 'retweeted_status'):
            return
        
        description = status.user.description
        loc = status.user.location
        retweets = status.retweet_count
        favourites = status.favorite_count
        followers_count = status.user.followers_count
        text = status.text
        place = status.place.full_name
        coords = status.coordinates
        name = status.user.screen_name
        created_at = status.created_at
        
        blob = textblob.TextBlob(text)
        sentiment = blob.sentiment
        
        # only return geotagged tweets         
        if coords is None:
            return
            
        # encode to json         
        if coords is not None:
            coords = json.dumps(coords)
            coords = json.loads(coords)            
            lon = coords['coordinates'][0]
            lat = coords['coordinates'][1]
        
        # create reference point for db         
        table = db["tweets"]
        
        # try to insert to sqlite db         
        try:
            table.insert(dict(
                created_at = created_at,
                retweets = retweets,
                favourites = favourites,
                user_description=description,
                followers_count = followers_count,
                user_location=loc,
                place=place,
                lat=lat,
                lon=lon,
                text=text,
                user_name=name,
                polarity = sentiment.polarity,
                subjectivity = sentiment.subjectivity
            ))
        # catch any error          
        except ProgrammingError as err:
            logging.INFO(err)

    def on_error(self, status_code):
        # if being rate limited, return false         
        if status_code == 420:
            return False
        
def timeout_test(func):
    
    def wrapper(*args):
        t = time.clock()
        res = func(*args)
        print(func.__name__, time.clock() - t)
        return res
    
    return wrapper

@timeout_test # scrap = timer(call_scraper)
def call_scraper(geo):
    # instantiate streamlistener object from class
    stream_listener = StreamListener()

    # connect to twitter API to create stream object
    stream = tweepy.Stream(auth=api.auth, listener=stream_listener)

    # apply custom filtering
    stream.filter(locations=geo, languages=['en'])

# %%
import logging

# set logger
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='twitter_log.log', mode='a')
formatter = logging.Formatter('%(asctime)s %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.DEBUG)

# set geo
bbox_geo = [-10.8544921875, 49.82380908513249, 2.021484375, 59.478568831926395]

# call function with decorator method
call_scraper(bbox_geo)
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# c:\xampp\htdocs\conda\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     255         try:
# --> 256             return self.connection.recv_into(*args, **kwargs)
#     257         except OpenSSL.SSL.SysCallError as e:
#
# c:\xampp\htdocs\conda\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1334             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1335         self._raise_ssl_error(self._ssl, result)
#    1336
#
# c:\xampp\htdocs\conda\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1148         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1149             raise WantReadError()
#    1150         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-2765d1cb048a> in <module>()
#      13
#      14 # call function with decorator method
# ---> 15 call_scraper(bbox_geo)
#
# <ipython-input-54-cbfff3c264c5> in wrapper(*args)
#      99     def wrapper(*args):
#     100         t = time.clock()
# --> 101         res = func(*args)
#     102         print(func.__name__, time.clock() - t)
#     103         return res
#
# <ipython-input-54-cbfff3c264c5> in call_scraper(geo)
#     114
#     115     # apply custom filtering
# --> 116     stream.filter(locations=geo, languages=['en'])
#
# c:\xampp\htdocs\conda\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# c:\xampp\htdocs\conda\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# c:\xampp\htdocs\conda\lib\site-packages\tweepy\streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# c:\xampp\htdocs\conda\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# c:\xampp\htdocs\conda\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# c:\xampp\htdocs\conda\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     378             else:
#     379                 cache_content = False
# --> 380                 data = self._fp.read(amt)
#     381                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     382                     # Close the connection when no data is returned
#
# c:\xampp\htdocs\conda\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# c:\xampp\htdocs\conda\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# c:\xampp\htdocs\conda\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# c:\xampp\htdocs\conda\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# c:\xampp\htdocs\conda\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# c:\xampp\htdocs\conda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# c:\xampp\htdocs\conda\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     267         except OpenSSL.SSL.WantReadError:
#     268             rd, wd, ed = select.select(
# --> 269                 [self.socket], [], [], self.socket.gettimeout())
#     270             if not rd:
#     271                 raise timeout('The read operation timed out')
#
# KeyboardInterrupt:

# %%
# connect to sqlite database
db = dataset.connect("sqlite:///tweets_lse.db")

# return all from database instance
result = db["tweets"].all()

# dump sqlite to csv
dataset.freeze(result, format='csv', filename='twitter_lse.csv')

# %%
cnx = sqlite3.connect(os.path.join(os.path.dirname('__file__'), 'tweets_lse.db'))

#  query sqlite table
lse_df = pd.read_sql_query('SELECT * FROM tweets', cnx)

lse_df
# Out:
#     id                  created_at  retweets  favourites  \
# 0    1  2017-07-07 11:50:04.000000         0           0
# 1    2  2017-07-07 11:50:06.000000         0           0
# 2    3  2017-07-07 11:50:07.000000         0           0
# 3    4  2017-07-07 11:50:08.000000         0           0
# 4    5  2017-07-07 11:50:09.000000         0           0
# 5    6  2017-07-07 11:50:09.000000         0           0
# 6    7  2017-07-07 11:50:12.000000         0           0
# 7    8  2017-07-07 11:50:15.000000         0           0
# 8    9  2017-07-07 11:50:17.000000         0           0
# 9   10  2017-07-07 11:50:22.000000         0           0
# 10  11  2017-07-07 11:50:23.000000         0           0
# 11  12  2017-07-07 11:50:24.000000         0           0
# 12  13  2017-07-07 11:50:28.000000         0           0
# 13  14  2017-07-07 11:50:29.000000         0           0
# 14  15  2017-07-07 11:50:30.000000         0           0
# 15  16  2017-07-07 11:50:36.000000         0           0
# 16  17  2017-07-07 11:50:39.000000         0           0
# 17  18  2017-07-07 11:50:39.000000         0           0
# 18  19  2017-07-07 11:50:42.000000         0           0
# 19  20  2017-07-07 11:50:48.000000         0           0
# 20  21  2017-07-07 11:50:49.000000         0           0
# 21  22  2017-07-07 11:50:49.000000         0           0
# 22  23  2017-07-07 11:50:54.000000         0           0
# 23  24  2017-07-07 11:50:56.000000         0           0
# 24  25  2017-07-07 11:50:56.000000         0           0
# 25  26  2017-07-07 11:50:58.000000         0           0
# 26  27  2017-07-07 11:51:00.000000         0           0
# 27  28  2017-07-07 11:51:06.000000         0           0
# 28  29  2017-07-07 11:51:08.000000         0           0
# 29  30  2017-07-07 11:51:10.000000         0           0
# 30  31  2017-07-07 11:51:12.000000         0           0
# 31  32  2017-07-07 11:51:13.000000         0           0
# 32  33  2017-07-07 11:51:14.000000         0           0
# 33  34  2017-07-07 11:51:15.000000         0           0
# 34  35  2017-07-07 11:51:16.000000         0           0
# 35  36  2017-07-07 11:51:17.000000         0           0
# 36  37  2017-07-07 11:51:17.000000         0           0
# 37  38  2017-07-07 11:51:17.000000         0           0
# 38  39  2017-07-07 11:51:18.000000         0           0
# 39  40  2017-07-07 11:51:18.000000         0           0
#
#                                      user_description  followers_count  \
# 0   Celebrity MakeupArtist for TV/Film, Music Vide...             2023
# 1   Real Time Solar updates from Oxford. See the s...               48
# 2   Weather conditions updated every 10 minutes fr...              828
# 3   (As Seen On The Only Way Is Essex) •Sunbeds •H...             8810
# 4   International stylist, colour evangelist. Spea...              573
# 5                                 | skins & ivories |             1544
# 6   Hi I am Mitchell! I am 23 years old, love Poké...                7
# 7       방탄소년단 —— teamwork makes the dream work. #정국 ♡              221
# 8                                Farm vet, Yorkshire.               58
# 9   Cancer survivor and blogger, CSR and animal lo...              586
# 10  Exiled Wiganer. Wigan Warriors🏉 LFC⚽\nVideo Ga...             3375
# 11                     photographer / London and Kent               13
# 12  Follow this account for geo-targeted Sales job...              540
# 13  If you like fashion, footwear and accessories ...             1727
# 14  Listing the latest properties for sale on MyHo...             1469
# 15  Mid twenties :: Aussie :: Traveller :: Designe...              316
# 16  Poet, former person, and editorial assistant f...              883
# 17  Dedicated Ale Man | Eclectic Music Lover | Ex-...              496
# 18  Australian Englander Man Mid-30-ish SW-London ...              342
# 19  digital marketing executive // @dreamthatday 🏠...              126
# 20                           don't tell mohohohohohom             1417
# 21  Celebrity MakeupArtist for TV/Film, Music Vide...             2023
# 22          This is who I am. You can like it or not.              792
# 23  Diamond Dolls Beauty-HAIR-NAILS-BEAUTY. we do ...              380
# 24  ClickJones LTD  \nCreative & Commercial\nPhoto...              301
# 25  Dyson Stylist and QVC Guest Presenter. Pilates...             1779
# 26  Express the utmost with the minimum : All book...            14699
# 27  Real Time Solar updates from Oxford. See the s...               48
# 28  Describe myself in 3 words? Cool As Fuck      ...              357
# 29  The-Driving-Academy brings together some of th...              247
# 30  professional vocalist, world traveler, entrepr...              351
# 31  Winners of "Best Place to Eat 2017." - 12 Quee...              698
# 32  We are a boutique private members’ club in the...             4419
# 33   Distinctive and luxurious accessories for brides             1111
# 34  Personal Trainer. Wolves UK.\n\nMyProtein Affi...              297
# 35  Outdoor Physical training Fitness for All Abil...              312
# 36  Photographer. Polish by birth, Glaswegian by c...              768
# 37                                      I'm so urban.              134
# 38  Lean Agile Project Manager at Springer Nature....              748
# 39   Basically... waiting for a mad man in a blue box              576
#
#                     user_location                      place        lat  \
# 0        Slough, Heathrow London.         Slough, South East  51.510000
# 1                          Oxford            Oxford, England  51.724849
# 2                 Woking, England         Woking, South East  51.332222
# 3   217 Highstreet Epping, Essex              Hertford, East  51.796091
# 4                 London, England             Ealing, London  51.511100
# 5                          London          Islington, London  51.534370
# 6        Perth, Western Australia             Merton, London  51.434360
# 7                            None          Bicester, England  51.892040
# 8                   York, England            Murton, England  53.963720
# 9                          London              East, England  51.727950
# 10           Wokingham, Berkshire           Reading, England  51.454600
# 11          Maidstone, South East              Deal, England  51.224459
# 12                         London            London, England  51.507351
# 13                        #Surrey         Haslemere, England  51.087163
# 14                        Ireland          Kilkenny, Ireland  52.666707
# 15                London, England            Hackney, London  51.526205
# 16                      Essex, UK        South East, England  51.872000
# 17             Gildersome, Leeds               York, England  53.956600
# 18                London, England          Esher, South East  51.391242
# 19             Liverpool, England            London, England  51.510481
# 20                           Hull        Nottingham, England  52.952631
# 21       Slough, Heathrow London.         Slough, South East  51.510000
# 22                         Milano            London, England  51.513289
# 23                          Derby             Derby, England  52.897343
# 24                Birmingham City        Birmingham, England  52.487484
# 25                     Birmingham        Birmingham, England  52.478130
# 26                    London City            London, England  51.507115
# 27                         Oxford            Oxford, England  51.724849
# 28                          Stoke    Stoke-on-Trent, England  52.988000
# 29            The-Driving-Academy   Bishop Auckland, England  54.656335
# 30           Hong Kong, Hong Kong            London, England  51.507115
# 31            Louth, Lincolnshire             Louth, England  53.366343
# 32                   Notting Hill         Kensington, London  51.513966
# 33                  Bath, England  Bradford-on-Avon, England  51.348194
# 34         Wolverhampton, England          Tottenham, London  51.594521
# 35         West Midlands, England          Redditch, England  52.307462
# 36                    Glasgow, UK          Glasgow, Scotland  55.865856
# 37                       Brighton         Paddington, London  51.529683
# 38                     London, UK        Camden Town, London  51.530300
# 39                      Poole, UK     Hopton on Sea, England  52.534816
#
#          lon                                               text  \
# 0  -0.593100  FEMALE MODELS NEEDED for NEXT WEEK - 11am to 3...
# 1  -1.232882  2879 watts.\n73% Battery = 1.46kWh https://t.c...
# 2  -0.557778  Tmp 32.9°C Wind 10mph Press 1013.2mb Cloud 900...
# 3  -0.076074  ✨✨👌🏽FRESH HAIR FRIDAY!!👌🏽✨✨\n\n•Blow By Junior...
# 4  -0.307228  Do your thing your way, it's the only way.\n\n...
# 5  -0.106129  last night's fun. @ O2 Academy Islington https...
# 6  -0.214262  Finally at #Wimbledon for the first time!! Goi...
# 7  -1.155603  (at @BicesterVillage in Bicester, Oxfordshire)...
# 8  -1.009620  Just in time for the weekend!! #craftginclub @...
# 9  -0.469812  Amazing #wedding last night! @ Shendish Manor ...
# 10 -0.963194  Drinking a American Pale Ale by @shipyardbrewi...
# 11  1.404157  Enjoying the #greatbritishsummer ☺️🏖\n\n#summe...
# 12 -0.127758  Want to work in #London? View our latest openi...
# 13 -0.709178  I love katherineleeper in this monochrome outf...
# 14 -7.234951  15 Ashfield, Golf Links Road, Kilkenny, Kil.. ...
# 15 -0.083280  Flowers from @love_work_life . It has been a g...
# 16 -1.565000  Beautiful, understated, reeks of a open heart....
# 17 -1.090010  Drinking a Mojave Rye Pale by @trackbrewco at ...
# 18 -0.333126  @iamanthonyjames We haven’t seen your new haircut
# 19 -0.135996  I'm at @WholeFoods Market in London, UK https:...
# 20 -1.139753  (last blink spam I swear) \nthis was just a sh...
# 21 -0.593100  FEMALE MODELS NEEDED for NEXT WEEK - 11am to 3...
# 22 -0.139034  Just Carnaby! I❤️London #love #prideinlondon #...
# 23 -1.430808  Short and effective Russian volume lashes by D...
# 24 -1.915091  Focused on @teiiichicken \n\n#ClickJones #fash...
# 25 -1.898660  Supersonic Experience johnlewisretail grandcen...
# 26 -0.127318  SP:MC &amp; I invite you to the first ZonesLDN...
# 27 -1.232882  2860 watts.\n73% Battery = 1.46kWh https://t.c...
# 28 -2.175623  Cracking view from the media centre @ Stoke Ci...
# 29 -1.705172  What another great result!🚗🚗💨💨 First time pass...
# 30 -0.127318  Struttin' into the weekend like...heyyyyy 💋 #m...
# 31 -0.003663  World Chocolate Day, because you need an excus...
# 32 -0.199651  Let us show you the secrets of a great midsect...
# 33 -2.251259  The Livia headband- part of our popular Livia ...
# 34 -0.112619  #Repost @g_whit1 (get_repost)\n・・・\nThat Frida...
# 35 -1.905345  Hot sunny session this morning but good turnou...
# 36 -4.268387  From promo shoot with @monkoora / hot_gem_tune...
# 37 -0.172012  Lovely day for it #engvsSA @ Lord's Cricket Gr...
# 38 -0.123600  Fish in the canal! #london #kingscross #fish #...
# 39  1.732152  4 years ago today I met @the_overtones for the...
#
#           user_name  polarity  subjectivity
# 0        RizKhanMua  0.000000      0.083333
# 1   OxfordSolarLive  0.000000      0.000000
# 2     WeatherWoking  0.208333      0.750000
# 3       SoGlamEssex  0.000000      0.000000
# 4    Jobaldwintrott  0.216667      0.716667
# 5       jimmolyneux  0.150000      0.133333
# 6      mitchoishere  0.347656      0.408333
# 7   palmypattareeya  0.000000      0.000000
# 8    ashmarshallvet  0.000000      0.000000
# 9        alexsam_89  0.300000      0.483333
# 10       wotnogravy -0.070000      0.060000
# 11        krupennyk  0.500000      0.600000
# 12    tmj_lon_sales  0.500000      0.900000
# 13  WoodieandMorris  0.350000      0.400000
# 14      NewToMyHome  0.000000      0.000000
# 15   georgieluxford  0.800000      0.750000
# 16     GrantTarbard  0.425000      0.750000
# 17  SimonWKimberley -0.210000      0.180000
# 18         drwormau  0.136364      0.454545
# 19       ceoreillyx  0.000000      0.000000
# 20        lonerrism  0.000000      0.183333
# 21       RizKhanMua  0.000000      0.083333
# 22          isteflo  0.500000      0.600000
# 23     DDollsBeauty  0.200000      0.366667
# 24    ClickandJones  0.000000      0.000000
# 25    TracieBedwood  0.000000      0.000000
# 26        PaulJubei  0.250000      0.333333
# 27  OxfordSolarLive  0.000000      0.000000
# 28      rugmaster87  0.000000      0.000000
# 29  drivingacademy_  0.525000      0.541667
# 30    tcollinsmusic  0.000000      0.000000
# 31    TheRanchLouth  0.316667      0.416667
# 32    BodyWorksWest  0.800000      0.750000
# 33  brittenweddings  0.550000      0.750000
# 34    Ste_J_Fitness  0.000000      0.000000
# 35        Outdoorpt  0.483333      0.816667
# 36       kriskesiak  0.000000      0.000000
# 37       lizziebaby  0.500000      0.750000
# 38         Jon_Reed  0.000000      0.000000
# 39  ManseyOvertones  0.000000      0.000000

# %%
import json
import random
import sys

from expects import expect, equal
from expects.matchers.built_in import be_above
from expects.matchers.built_in.have_keys import have_key

import pytest
from requests import *
from pprint import pprint

sys.path.insert(0, './python')

import conftest
import factories

# %%
content = lse_df.loc[0]['text']
content
# Out:
# 'FEMALE MODELS NEEDED for NEXT WEEK - 11am to 3pm -TFP HAIR N MAKEUP on - mon 10th july, tues… https://t.co/1f66MQ4Weh'

# %%
# define constants
BASE_URL = 'https://api.receptiviti.com/'
APIKEY = '595f54e5572c16057117ff51'
APISECRET = 'DDG2alP30PiobcqCuyspe57U9hK780FuoGUG2mC4NiQ'

@pytest.mark.person_api
def test_create_person_with_content(baseurl, apikey, apisecret):
    content_data = factories.get_content_data()
    person_data = factories.get_person_data(content_data)

    person_api_url = conftest.person_api_url(baseurl)
    auth_headers = conftest.auth_headers(apikey, apisecret)
    
    response = post(person_api_url, json=person_data, headers=auth_headers)

    response_json = json.loads(response.content)
    expect(response.status_code).to(equal(200))
    expect(response_json["name"]).to(equal(person_data["name"]))
    expect(response_json["contents"][0]).to(have_key("receptiviti_scores"))
    expect(response_json["contents"][0]).to(have_key("liwc_scores"))
    
    return response_json

test_case = test_create_person_with_content(baseurl=BASE_URL,
                                apikey=APIKEY,
                                apisecret=APISECRET)

pprint(test_case)
# Out:
# {'_id': '595f7769572c16057117ff6c',
#  '_links': {'contents': {'href': '/v2/api/person/595f7769572c16057117ff6c/contents',
#                          'method': 'GET'},
#             'self': {'href': '/v2/api/person/595f7769572c16057117ff6c',
#                      'method': 'GET'}},
#  'content_count': 1,
#  'contents': [{'_id': '595f7769572c16057117ff6d',
#                'communication_recommendation': 'Try to focus on the '
#                                                'here-and-now instead of the '
#                                                "future. Don't be afraid to use "
#                                                'humor to lighten the '
#                                                'conversation. Give them some '
#                                                "time to talk - they'll tell "
#                                                "you what they're thinking.",
#                'content_date': '2017-07-07T12:58:29.661000+00:00',
#                'content_handle': '8ba77e529bda4e438f8ecfca7a6407d4',
#                'content_source': 2,
#                'content_tags': ['tag1', 'tag2', 'tag3'],
#                'created': '2017-07-07T11:58:33.798000+00:00',
#                'custom_fields': {},
#                'emotional_analysis': {'emotional_tone': {'rating': 'Negative',
#                                                          'score': 25.774195},
#                                       'facets': {'anger': 0.0,
#                                                  'fear': 0.0,
#                                                  'sad': 0.0}},
#                'language': 'english',
#                'liwc_scores': {'analytic': 98.98319,
#                                'authentic': 43.373333,
#                                'categories': {'AllPunc': 0.32,
#                                               'Apostro': 0.0,
#                                               'Colon': 0.0,
#                                               'Comma': 0.04,
#                                               'Dash': 0.12,
#                                               'Exclam': 0.0,
#                                               'OtherP': 0.08,
#                                               'Parenth': 0.0,
#                                               'Period': 0.08,
#                                               'QMark': 0.0,
#                                               'Quote': 0.0,
#                                               'SemiC': 0.0,
#                                               'achieve': 0.0,
#                                               'adj': 0.08,
#                                               'adverb': 0.0,
#                                               'affect': 0.0,
#                                               'affiliation': 0.0,
#                                               'anger': 0.0,
#                                               'anx': 0.0,
#                                               'article': 0.0,
#                                               'assent': 0.0,
#                                               'auxverb': 0.0,
#                                               'bio': 0.0,
#                                               'body': 0.0,
#                                               'cause': 0.0,
#                                               'certain': 0.0,
#                                               'cogproc': 0.04,
#                                               'compare': 0.0,
#                                               'conj': 0.0,
#                                               'death': 0.0,
#                                               'differ': 0.0,
#                                               'discrep': 0.04,
#                                               'drives': 0.0,
#                                               'family': 0.0,
#                                               'feel': 0.0,
#                                               'female': 0.04,
#                                               'filler': 0.0,
#                                               'focusfuture': 0.0,
#                                               'focuspast': 0.04,
#                                               'focuspresent': 0.0,
#                                               'friend': 0.0,
#                                               'function': 0.12,
#                                               'health': 0.0,
#                                               'hear': 0.0,
#                                               'home': 0.0,
#                                               'i': 0.0,
#                                               'informal': 0.04,
#                                               'ingest': 0.0,
#                                               'insight': 0.0,
#                                               'interrog': 0.0,
#                                               'ipron': 0.0,
#                                               'leisure': 0.0,
#                                               'male': 0.0,
#                                               'money': 0.0,
#                                               'motion': 0.0,
#                                               'negate': 0.0,
#                                               'negemo': 0.0,
#                                               'netspeak': 0.04,
#                                               'nonflu': 0.0,
#                                               'number': 0.0,
#                                               'percept': 0.0,
#                                               'posemo': 0.0,
#                                               'power': 0.0,
#                                               'ppron': 0.0,
#                                               'prep': 0.12,
#                                               'pronoun': 0.0,
#                                               'quant': 0.0,
#                                               'relativ': 0.24,
#                                               'relig': 0.0,
#                                               'reward': 0.0,
#                                               'risk': 0.0,
#                                               'sad': 0.0,
#                                               'see': 0.0,
#                                               'sexual': 0.0,
#                                               'shehe': 0.0,
#                                               'social': 0.04,
#                                               'space': 0.04,
#                                               'swear': 0.0,
#                                               'tentat': 0.0,
#                                               'they': 0.0,
#                                               'time': 0.2,
#                                               'verb': 0.04,
#                                               'we': 0.0,
#                                               'work': 0.0,
#                                               'you': 0.0},
#                                'clout': 65.55556,
#                                'dic': 0.44,
#                                'sixLtr': 0.0,
#                                'tone': 25.774195,
#                                'wc': 25,
#                                'wps': 25.0},
#                'organa_scores': {},
#                'person': '595f7769572c16057117ff6c',
#                'personality_snapshot': [{'description': 'Likely has good '
#                                                         'social skills and '
#                                                         'typically gets along '
#                                                         'well with others. '
#                                                         'Likely a relatively '
#                                                         'grounded person who '
#                                                         'values friendships, '
#                                                         'works hard, and has '
#                                                         'healthy life goals.',
#                                          'summary': 'Well-adjusted'},
#                                         {'description': 'Focused on the needs '
#                                                         'of the group. Places '
#                                                         'importance on harmony '
#                                                         'and close bonds with '
#                                                         'others. Prefers that '
#                                                         'everyone has a voice '
#                                                         'when making '
#                                                         'decisions. Likes '
#                                                         'peaceful '
#                                                         'interactions, '
#                                                         'dislikes conflict and '
#                                                         'people who assert '
#                                                         'themselves over '
#                                                         'others.',
#                                          'summary': 'Harmony-seeking'},
#                                         {'description': 'Typcally able to '
#                                                         'remain calm in the '
#                                                         'face of stressful or '
#                                                         'unpleasant '
#                                                         'situations.',
#                                          'summary': 'Calm and collected'}],
#                'receptiviti_scores': {'percentiles': {'active': 94.53046109392167,
#                                                       'adjustment': 99,
#                                                       'adventurous': 5.19343872510631,
#                                                       'aggressive': 10.941670106094325,
#                                                       'agreeableness': 58.17278830443361,
#                                                       'ambitious': 2.5342615784244678,
#                                                       'anxious': 4.027629386597629,
#                                                       'artistic': 5.568196786788832,
#                                                       'assertive': 8.264724663739113,
#                                                       'body_focus': 37.14380569526287,
#                                                       'cautious': 12.98141911819454,
#                                                       'cheerful': 69.20707464975462,
#                                                       'cold': 60.892196856426935,
#                                                       'conscientiousness': 28.426683409277206,
#                                                       'cooperative': 19.583575685532967,
#                                                       'depression': 73.48667783431974,
#                                                       'disciplined': 67.58781268823734,
#                                                       'dutiful': 54.45555137427064,
#                                                       'emotionally_aware': 37.81210962014671,
#                                                       'empathetic': 37.845022623050234,
#                                                       'energetic': 34.05776778046357,
#                                                       'extraversion': 55.21369280423966,
#                                                       'family_oriented': 5.341406271213504,
#                                                       'food_focus': 37.34654929608604,
#                                                       'friend_focus': 35.71835323821346,
#                                                       'friendly': 51.02997302155532,
#                                                       'generous': 68.87089106072321,
#                                                       'genuine': 72.20552261200179,
#                                                       'happiness': 45.373971634856105,
#                                                       'health_oriented': 34.4753155240238,
#                                                       'humble': 37.677638173026125,
#                                                       'imaginative': 74.8082516750301,
#                                                       'impulsive': 9.759871017651372,
#                                                       'independent': 83.06758374302856,
#                                                       'insecure': 47.25055829209402,
#                                                       'intellectual': 1,
#                                                       'leisure_oriented': 28.191213239952088,
#                                                       'liberal': 44.514815941528866,
#                                                       'melancholy': 15.198541490612644,
#                                                       'money_oriented': 28.284758554044977,
#                                                       'netspeak_focus': 54.4013382968885,
#                                                       'neuroticism': 1.7023538979083177,
#                                                       'openness': 6.534507466193956,
#                                                       'organized': 48.99012835990381,
#                                                       'persuasive': 95.29356505207399,
#                                                       'power_driven': 1,
#                                                       'religion_oriented': 37.9459453631124,
#                                                       'reward_bias': 30.157076729880426,
#                                                       'self_assured': 35.44976506703212,
#                                                       'self_conscious': 11.420877128156548,
#                                                       'sexual_focus': 42.875012145316994,
#                                                       'sociable': 7.479566032212969,
#                                                       'social_skills': 77.79580163760478,
#                                                       'stressed': 8.773677682376045,
#                                                       'thinking_style': 53.63423545782969,
#                                                       'trusting': 9.452401592251892,
#                                                       'type_a': 11.142765621030998,
#                                                       'work_oriented': 1,
#                                                       'workhorse': 46.44570684269151},
#                                       'raw_scores': {'active': -2.5,
#                                                      'adjustment': 1.3387518640094904,
#                                                      'adventurous': -0.8620689655172414,
#                                                      'aggressive': 0.0,
#                                                      'agreeableness': -2.9739962522473915,
#                                                      'ambitious': 0.0,
#                                                      'anxious': -0.24330900243309,
#                                                      'artistic': 0.0,
#                                                      'assertive': 0.0,
#                                                      'body_focus': 0.0,
#                                                      'cautious': 0.0,
#                                                      'cheerful': -0.7182628062360803,
#                                                      'cold': 0.0,
#                                                      'conscientiousness': -0.06746031746031744,
#                                                      'cooperative': 0.0,
#                                                      'depression': 0.0,
#                                                      'disciplined': 2.5,
#                                                      'dutiful': -1.5873015873015872,
#                                                      'emotionally_aware': 0.9280742459396752,
#                                                      'empathetic': -1.6830294530154277,
#                                                      'energetic': 0.0,
#                                                      'extraversion': -0.5170003296057086,
#                                                      'family_oriented': -0.45139134744742626,
#                                                      'food_focus': 0.0,
#                                                      'friend_focus': 0.0,
#                                                      'friendly': 0.37700282752120645,
#                                                      'generous': -1.611103698955103,
#                                                      'genuine': 0.0,
#                                                      'happiness': 1.7817371937639197,
#                                                      'health_oriented': 0.0,
#                                                      'humble': -1.7817371937639197,
#                                                      'imaginative': 0.0,
#                                                      'impulsive': 0.0,
#                                                      'independent': 0.8943994553910665,
#                                                      'insecure': 0.4106776180698152,
#                                                      'intellectual': 0.0,
#                                                      'leisure_oriented': 0.0,
#                                                      'liberal': 0.0,
#                                                      'melancholy': 0.0,
#                                                      'money_oriented': 0.0,
#                                                      'netspeak_focus': 2.5,
#                                                      'neuroticism': 0.004836525907807532,
#                                                      'openness': -0.07960636850948076,
#                                                      'organized': 0.0,
#                                                      'persuasive': 3.021781317024918,
#                                                      'power_driven': -0.8169705469845723,
#                                                      'religion_oriented': 0.0,
#                                                      'reward_bias': 0.0,
#                                                      'self_assured': 0.0,
#                                                      'self_conscious': 0.0,
#                                                      'sexual_focus': 0.0,
#                                                      'sociable': 0.4106776180698152,
#                                                      'social_skills': 0.0,
#                                                      'stressed': 0.4106776180698152,
#                                                      'thinking_style': 0.9280742459396752,
#                                                      'trusting': -2.5,
#                                                      'type_a': 2.910677618069815,
#                                                      'work_oriented': 0.0,
#                                                      'workhorse': -1.5873015873015872},
#                                       'warnings': {'active': ['Insufficient '
#                                                               'word count. '
#                                                               'Requires a '
#                                                               'minimum of 500 '
#                                                               'words for '
#                                                               'accurate '
#                                                               'results.'],
#                                                    'adjustment': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '300 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'adventurous': ['Insufficient '
#                                                                    'word '
#                                                                    'count. '
#                                                                    'Requires a '
#                                                                    'minimum of '
#                                                                    '500 words '
#                                                                    'for '
#                                                                    'accurate '
#                                                                    'results.'],
#                                                    'aggressive': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '500 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'agreeableness': ['Insufficient '
#                                                                      'word '
#                                                                      'count. '
#                                                                      'Requires '
#                                                                      'a '
#                                                                      'minimum '
#                                                                      'of 200 '
#                                                                      'words '
#                                                                      'for '
#                                                                      'accurate '
#                                                                      'results.'],
#                                                    'ambitious': ['Insufficient '
#                                                                  'word count. '
#                                                                  'Requires a '
#                                                                  'minimum of '
#                                                                  '500 words '
#                                                                  'for accurate '
#                                                                  'results.'],
#                                                    'anxious': ['Insufficient '
#                                                                'word count. '
#                                                                'Requires a '
#                                                                'minimum of 500 '
#                                                                'words for '
#                                                                'accurate '
#                                                                'results.'],
#                                                    'artistic': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'assertive': ['Insufficient '
#                                                                  'word count. '
#                                                                  'Requires a '
#                                                                  'minimum of '
#                                                                  '500 words '
#                                                                  'for accurate '
#                                                                  'results.'],
#                                                    'body_focus': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '300 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'cautious': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'cheerful': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'cold': ['Insufficient word '
#                                                             'count. Requires a '
#                                                             'minimum of 200 '
#                                                             'words for '
#                                                             'accurate '
#                                                             'results.'],
#                                                    'conscientiousness': ['Insufficient '
#                                                                          'word '
#                                                                          'count. '
#                                                                          'Requires '
#                                                                          'a '
#                                                                          'minimum '
#                                                                          'of '
#                                                                          '200 '
#                                                                          'words '
#                                                                          'for '
#                                                                          'accurate '
#                                                                          'results.'],
#                                                    'cooperative': ['Insufficient '
#                                                                    'word '
#                                                                    'count. '
#                                                                    'Requires a '
#                                                                    'minimum of '
#                                                                    '500 words '
#                                                                    'for '
#                                                                    'accurate '
#                                                                    'results.'],
#                                                    'depression': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '300 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'disciplined': ['Insufficient '
#                                                                    'word '
#                                                                    'count. '
#                                                                    'Requires a '
#                                                                    'minimum of '
#                                                                    '500 words '
#                                                                    'for '
#                                                                    'accurate '
#                                                                    'results.'],
#                                                    'dutiful': ['Insufficient '
#                                                                'word count. '
#                                                                'Requires a '
#                                                                'minimum of 500 '
#                                                                'words for '
#                                                                'accurate '
#                                                                'results.'],
#                                                    'emotionally_aware': ['Insufficient '
#                                                                          'word '
#                                                                          'count. '
#                                                                          'Requires '
#                                                                          'a '
#                                                                          'minimum '
#                                                                          'of '
#                                                                          '500 '
#                                                                          'words '
#                                                                          'for '
#                                                                          'accurate '
#                                                                          'results.'],
#                                                    'empathetic': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '500 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'energetic': ['Insufficient '
#                                                                  'word count. '
#                                                                  'Requires a '
#                                                                  'minimum of '
#                                                                  '500 words '
#                                                                  'for accurate '
#                                                                  'results.'],
#                                                    'extraversion': ['Insufficient '
#                                                                     'word '
#                                                                     'count. '
#                                                                     'Requires '
#                                                                     'a minimum '
#                                                                     'of 200 '
#                                                                     'words for '
#                                                                     'accurate '
#                                                                     'results.'],
#                                                    'family_oriented': ['Insufficient '
#                                                                        'word '
#                                                                        'count. '
#                                                                        'Requires '
#                                                                        'a '
#                                                                        'minimum '
#                                                                        'of 300 '
#                                                                        'words '
#                                                                        'for '
#                                                                        'accurate '
#                                                                        'results.'],
#                                                    'food_focus': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '300 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'friend_focus': ['Insufficient '
#                                                                     'word '
#                                                                     'count. '
#                                                                     'Requires '
#                                                                     'a minimum '
#                                                                     'of 300 '
#                                                                     'words for '
#                                                                     'accurate '
#                                                                     'results.'],
#                                                    'friendly': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'generous': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'genuine': ['Insufficient '
#                                                                'word count. '
#                                                                'Requires a '
#                                                                'minimum of 500 '
#                                                                'words for '
#                                                                'accurate '
#                                                                'results.'],
#                                                    'happiness': ['Insufficient '
#                                                                  'word count. '
#                                                                  'Requires a '
#                                                                  'minimum of '
#                                                                  '300 words '
#                                                                  'for accurate '
#                                                                  'results.'],
#                                                    'health_oriented': ['Insufficient '
#                                                                        'word '
#                                                                        'count. '
#                                                                        'Requires '
#                                                                        'a '
#                                                                        'minimum '
#                                                                        'of 300 '
#                                                                        'words '
#                                                                        'for '
#                                                                        'accurate '
#                                                                        'results.'],
#                                                    'humble': ['Insufficient '
#                                                               'word count. '
#                                                               'Requires a '
#                                                               'minimum of 500 '
#                                                               'words for '
#                                                               'accurate '
#                                                               'results.'],
#                                                    'imaginative': ['Insufficient '
#                                                                    'word '
#                                                                    'count. '
#                                                                    'Requires a '
#                                                                    'minimum of '
#                                                                    '500 words '
#                                                                    'for '
#                                                                    'accurate '
#                                                                    'results.'],
#                                                    'impulsive': ['Insufficient '
#                                                                  'word count. '
#                                                                  'Requires a '
#                                                                  'minimum of '
#                                                                  '500 words '
#                                                                  'for accurate '
#                                                                  'results.'],
#                                                    'independent': ['Insufficient '
#                                                                    'word '
#                                                                    'count. '
#                                                                    'Requires a '
#                                                                    'minimum of '
#                                                                    '200 words '
#                                                                    'for '
#                                                                    'accurate '
#                                                                    'results.'],
#                                                    'insecure': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '200 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'intellectual': ['Insufficient '
#                                                                     'word '
#                                                                     'count. '
#                                                                     'Requires '
#                                                                     'a minimum '
#                                                                     'of 500 '
#                                                                     'words for '
#                                                                     'accurate '
#                                                                     'results.'],
#                                                    'leisure_oriented': ['Insufficient '
#                                                                         'word '
#                                                                         'count. '
#                                                                         'Requires '
#                                                                         'a '
#                                                                         'minimum '
#                                                                         'of '
#                                                                         '300 '
#                                                                         'words '
#                                                                         'for '
#                                                                         'accurate '
#                                                                         'results.'],
#                                                    'liberal': ['Insufficient '
#                                                                'word count. '
#                                                                'Requires a '
#                                                                'minimum of 500 '
#                                                                'words for '
#                                                                'accurate '
#                                                                'results.'],
#                                                    'melancholy': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '500 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'money_oriented': ['Insufficient '
#                                                                       'word '
#                                                                       'count. '
#                                                                       'Requires '
#                                                                       'a '
#                                                                       'minimum '
#                                                                       'of 300 '
#                                                                       'words '
#                                                                       'for '
#                                                                       'accurate '
#                                                                       'results.'],
#                                                    'netspeak_focus': ['Insufficient '
#                                                                       'word '
#                                                                       'count. '
#                                                                       'Requires '
#                                                                       'a '
#                                                                       'minimum '
#                                                                       'of 100 '
#                                                                       'words '
#                                                                       'for '
#                                                                       'accurate '
#                                                                       'results.'],
#                                                    'neuroticism': ['Insufficient '
#                                                                    'word '
#                                                                    'count. '
#                                                                    'Requires a '
#                                                                    'minimum of '
#                                                                    '200 words '
#                                                                    'for '
#                                                                    'accurate '
#                                                                    'results.'],
#                                                    'openness': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '200 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'organized': ['Insufficient '
#                                                                  'word count. '
#                                                                  'Requires a '
#                                                                  'minimum of '
#                                                                  '500 words '
#                                                                  'for accurate '
#                                                                  'results.'],
#                                                    'persuasive': ['Insufficient '
#                                                                   'word count. '
#                                                                   'Requires a '
#                                                                   'minimum of '
#                                                                   '200 words '
#                                                                   'for '
#                                                                   'accurate '
#                                                                   'results.'],
#                                                    'power_driven': ['Insufficient '
#                                                                     'word '
#                                                                     'count. '
#                                                                     'Requires '
#                                                                     'a minimum '
#                                                                     'of 300 '
#                                                                     'words for '
#                                                                     'accurate '
#                                                                     'results.'],
#                                                    'religion_oriented': ['Insufficient '
#                                                                          'word '
#                                                                          'count. '
#                                                                          'Requires '
#                                                                          'a '
#                                                                          'minimum '
#                                                                          'of '
#                                                                          '300 '
#                                                                          'words '
#                                                                          'for '
#                                                                          'accurate '
#                                                                          'results.'],
#                                                    'reward_bias': ['Insufficient '
#                                                                    'word '
#                                                                    'count. '
#                                                                    'Requires a '
#                                                                    'minimum of '
#                                                                    '200 words '
#                                                                    'for '
#                                                                    'accurate '
#                                                                    'results.'],
#                                                    'self_assured': ['Insufficient '
#                                                                     'word '
#                                                                     'count. '
#                                                                     'Requires '
#                                                                     'a minimum '
#                                                                     'of 500 '
#                                                                     'words for '
#                                                                     'accurate '
#                                                                     'results.'],
#                                                    'self_conscious': ['Insufficient '
#                                                                       'word '
#                                                                       'count. '
#                                                                       'Requires '
#                                                                       'a '
#                                                                       'minimum '
#                                                                       'of 500 '
#                                                                       'words '
#                                                                       'for '
#                                                                       'accurate '
#                                                                       'results.'],
#                                                    'sexual_focus': ['Insufficient '
#                                                                     'word '
#                                                                     'count. '
#                                                                     'Requires '
#                                                                     'a minimum '
#                                                                     'of 300 '
#                                                                     'words for '
#                                                                     'accurate '
#                                                                     'results.'],
#                                                    'sociable': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'social_skills': ['Insufficient '
#                                                                      'word '
#                                                                      'count. '
#                                                                      'Requires '
#                                                                      'a '
#                                                                      'minimum '
#                                                                      'of 200 '
#                                                                      'words '
#                                                                      'for '
#                                                                      'accurate '
#                                                                      'results.'],
#                                                    'stressed': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'thinking_style': ['Insufficient '
#                                                                       'word '
#                                                                       'count. '
#                                                                       'Requires '
#                                                                       'a '
#                                                                       'minimum '
#                                                                       'of 100 '
#                                                                       'words '
#                                                                       'for '
#                                                                       'accurate '
#                                                                       'results.'],
#                                                    'trusting': ['Insufficient '
#                                                                 'word count. '
#                                                                 'Requires a '
#                                                                 'minimum of '
#                                                                 '500 words for '
#                                                                 'accurate '
#                                                                 'results.'],
#                                                    'type_a': ['Insufficient '
#                                                               'word count. '
#                                                               'Requires a '
#                                                               'minimum of 200 '
#                                                               'words for '
#                                                               'accurate '
#                                                               'results.'],
#                                                    'work_oriented': ['Insufficient '
#                                                                      'word '
#                                                                      'count. '
#                                                                      'Requires '
#                                                                      'a '
#                                                                      'minimum '
#                                                                      'of 300 '
#                                                                      'words '
#                                                                      'for '
#                                                                      'accurate '
#                                                                      'results.'],
#                                                    'workhorse': ['Insufficient '
#                                                                  'word count. '
#                                                                  'Requires a '
#                                                                  'minimum of '
#                                                                  '300 words '
#                                                                  'for accurate '
#                                                                  'results.']}},
#                'updated': '2017-07-07T11:58:33.798000+00:00',
#                'user': '595f54e5572c16057117ff51'}],
#  'created': '2017-07-07T11:58:33.726000+00:00',
#  'custom_fields': {},
#  'gender': 1,
#  'name': 'John 3db74552df174400b4022bc777723094 Doe',
#  'person_handle': '4e0948ada6bb489aa5d33104dee5f8cd',
#  'person_tags': [],
#  'updated': '2017-07-07T11:58:33.726000+00:00',
#  'user': '595f54e5572c16057117ff51'}
